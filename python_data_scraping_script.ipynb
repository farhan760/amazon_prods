# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# List of products (stored in a JSON file, but loading here for simplicity)
products = ["headphones", "smartphones", "laptops", "cameras", "watches", "tablets", "monitors", "printers", "speakers", "drones"]

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

# Base URL with placeholders for product and page
base_url = "https://www.amazon.com/s?k={product}&page={page}"

# Function to scrape data from a single page
def scrape_page(product, page):
    url = base_url.format(product=product, page=page)
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    items = soup.find_all("div", {"data-component-type": "s-search-result"})

    results = []
    for item in items:
        try:
            title = item.h2.text.strip()
            reviews = item.find("span", {"class": "a-size-base"})
            total_reviews = reviews.text.strip() if reviews else "No reviews"
            price_whole = item.find("span", {"class": "a-price-whole"})
            price_fraction = item.find("span", {"class": "a-price-fraction"})
            price = f"{price_whole.text.strip()}.{price_fraction.text.strip()}" if price_whole and price_fraction else "Price not available"
            image = item.find("img", {"class": "s-image"})["src"] if item.find("img", {"class": "s-image"}) else "Image not available"

            results.append({
                "Title": title,
                "Total Reviews": total_reviews,
                "Price": price,
                "Image URL": image,
            })
        except Exception as e:
            print(f"Error parsing item: {e}")

    return results

# Main scraping loop
all_data = {}

for product in products:
    product_data = []
    print(f"Scraping product: {product}")
    for page in range(1, 21):  # Scraping pages 1 to 20
        print(f"Scraping page {page} for {product}")
        page_data = scrape_page(product, page)
        product_data.extend(page_data)
        time.sleep(2)  # Be polite and avoid being blocked

    all_data[product] = product_data

# Save data to a JSON file
with open("amazon_products.json", "w") as f:
    json.dump(all_data, f, indent=4)

print("Scraping completed. Data saved to 'amazon_products.json'")
# Out:
# Scraping product: headphones
# Scraping page 1 for headphones
# Scraping page 2 for headphones
# Scraping page 3 for headphones
# Scraping page 4 for headphones
# Scraping page 5 for headphones
# Scraping page 6 for headphones
# Scraping page 7 for headphones
# Scraping page 8 for headphones
# Scraping page 9 for headphones
# Scraping page 10 for headphones
# Scraping page 11 for headphones
# Scraping page 12 for headphones
# Scraping page 13 for headphones
# Scraping page 14 for headphones
# Scraping page 15 for headphones
# Scraping page 16 for headphones
# Scraping page 17 for headphones
# Scraping page 18 for headphones
# Scraping page 19 for headphones
# Scraping page 20 for headphones
# Scraping product: smartphones
# Scraping page 1 for smartphones
# Scraping page 2 for smartphones
# Scraping page 3 for smartphones
# Scraping page 4 for smartphones
# Scraping page 5 for smartphones
# Scraping page 6 for smartphones
# Scraping page 7 for smartphones
# Scraping page 8 for smartphones
# Scraping page 9 for smartphones
# Scraping page 10 for smartphones
# Scraping page 11 for smartphones
# Scraping page 12 for smartphones
# Scraping page 13 for smartphones
# Scraping page 14 for smartphones
# Scraping page 15 for smartphones
# Scraping page 16 for smartphones
# Scraping page 17 for smartphones
# Scraping page 18 for smartphones
# Scraping page 19 for smartphones
# Scraping page 20 for smartphones
# Scraping product: laptops
# Scraping page 1 for laptops
# Scraping page 2 for laptops
# Scraping page 3 for laptops
# Scraping page 4 for laptops
# Scraping page 5 for laptops
# Scraping page 6 for laptops
# Scraping page 7 for laptops
# Scraping page 8 for laptops
# Scraping page 9 for laptops
# Scraping page 10 for laptops
# Scraping page 11 for laptops
# Scraping page 12 for laptops
# Scraping page 13 for laptops
# Scraping page 14 for laptops
# Scraping page 15 for laptops
# Scraping page 16 for laptops
# Scraping page 17 for laptops
# Scraping page 18 for laptops
# Scraping page 19 for laptops
# Scraping page 20 for laptops
# Scraping product: cameras
# Scraping page 1 for cameras
# Scraping page 2 for cameras
# Scraping page 3 for cameras
# Scraping page 4 for cameras
# Scraping page 5 for cameras
# Scraping page 6 for cameras
# Scraping page 7 for cameras
# Scraping page 8 for cameras
# Scraping page 9 for cameras
# Scraping page 10 for cameras
# Scraping page 11 for cameras
# Scraping page 12 for cameras
# Scraping page 13 for cameras
# Scraping page 14 for cameras
# Scraping page 15 for cameras
# Scraping page 16 for cameras
# Scraping page 17 for cameras
# Scraping page 18 for cameras
# Scraping page 19 for cameras
# Scraping page 20 for cameras
# Scraping product: watches
# Scraping page 1 for watches
# Scraping page 2 for watches
# Scraping page 3 for watches
# Scraping page 4 for watches
# Scraping page 5 for watches
# Scraping page 6 for watches
# Scraping page 7 for watches
# Scraping page 8 for watches
# Scraping page 9 for watches
# Scraping page 10 for watches
# Scraping page 11 for watches
# Scraping page 12 for watches
# Scraping page 13 for watches
# Scraping page 14 for watches
# Scraping page 15 for watches
# Scraping page 16 for watches
# Scraping page 17 for watches
# Scraping page 18 for watches
# Scraping page 19 for watches
# Scraping page 20 for watches
# Scraping product: tablets
# Scraping page 1 for tablets
# Scraping page 2 for tablets
# Scraping page 3 for tablets
# Scraping page 4 for tablets
# Scraping page 5 for tablets
# Scraping page 6 for tablets
# Scraping page 7 for tablets
# Scraping page 8 for tablets
# Scraping page 9 for tablets
# Scraping page 10 for tablets
# Scraping page 11 for tablets
# Scraping page 12 for tablets
# Scraping page 13 for tablets
# Scraping page 14 for tablets
# Scraping page 15 for tablets
# Scraping page 16 for tablets
# Scraping page 17 for tablets
# Scraping page 18 for tablets
# Scraping page 19 for tablets
# Scraping page 20 for tablets
# Scraping product: monitors
# Scraping page 1 for monitors
# Scraping page 2 for monitors
# Scraping page 3 for monitors
# Scraping page 4 for monitors
# Scraping page 5 for monitors
# Scraping page 6 for monitors
# Scraping page 7 for monitors
# Scraping page 8 for monitors
# Scraping page 9 for monitors
# Scraping page 10 for monitors
# Scraping page 11 for monitors
# Scraping page 12 for monitors
# Scraping page 13 for monitors
# Scraping page 14 for monitors
# Scraping page 15 for monitors
# Scraping page 16 for monitors
# Scraping page 17 for monitors
# Scraping page 18 for monitors
# Scraping page 19 for monitors
# Scraping page 20 for monitors
# Scraping product: printers
# Scraping page 1 for printers
# Scraping page 2 for printers
# Scraping page 3 for printers
# Scraping page 4 for printers
# Scraping page 5 for printers
# Scraping page 6 for printers
# Scraping page 7 for printers
# Scraping page 8 for printers
# Scraping page 9 for printers
# Scraping page 10 for printers
# Scraping page 11 for printers
# Scraping page 12 for printers
# Scraping page 13 for printers
# Scraping page 14 for printers
# Scraping page 15 for printers
# Scraping page 16 for printers
# Scraping page 17 for printers
# Scraping page 18 for printers
# Scraping page 19 for printers
# Scraping page 20 for printers
# Scraping product: speakers
# Scraping page 1 for speakers
# Scraping page 2 for speakers
# Scraping page 3 for speakers
# Scraping page 4 for speakers
# Scraping page 5 for speakers
# Scraping page 6 for speakers
# Scraping page 7 for speakers
# Scraping page 8 for speakers
# Scraping page 9 for speakers
# Scraping page 10 for speakers
# Scraping page 11 for speakers
# Scraping page 12 for speakers
# Scraping page 13 for speakers
# Scraping page 14 for speakers
# Scraping page 15 for speakers
# Scraping page 16 for speakers
# Scraping page 17 for speakers
# Scraping page 18 for speakers
# Scraping page 19 for speakers
# Scraping page 20 for speakers
# Scraping product: drones
# Scraping page 1 for drones
# Scraping page 2 for drones
# Scraping page 3 for drones
# Scraping page 4 for drones
# Scraping page 5 for drones
# Scraping page 6 for drones
# Scraping page 7 for drones
# Scraping page 8 for drones
# Scraping page 9 for drones
# Scraping page 10 for drones
# Scraping page 11 for drones
# Scraping page 12 for drones
# Scraping page 13 for drones
# Scraping page 14 for drones
# Scraping page 15 for drones
# Scraping page 16 for drones
# Scraping page 17 for drones
# Scraping page 18 for drones
# Scraping page 19 for drones
# Scraping page 20 for drones
# Scraping completed. Data saved to 'amazon_products.json'
